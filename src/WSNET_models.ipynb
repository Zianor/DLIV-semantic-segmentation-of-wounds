# %% [markdown]
# ## Model Linknet Local
# (https://github.com/subbareddy248/WSNET/blob/main/Code/Medical_CNN_Linknet-Local.py)

# %%
from src.WSNET.Medical_CNN_Linknet_Local import get_linknet_local_model
model_linknet_local, train_gen_linknet_local, val_gen_linknet_local, test_gen_linknet_local = get_linknet_local_model()
# Out:
# /Users/zianor/Documents/repos/DLIV-chronic-wound-segmentation/venv/lib/python3.8/site-packages/keras_applications/mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 192, 192, 3)]        0         []
#
#  create_patches_1 (CreatePa  [(None, 64, 64, 3),          0         ['input_3[0][0]']
#  tches)                       (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3)]
#
#  model_2 (Functional)        (None, 64, 64, 1)            4546065   ['create_patches_1[0][0]',
#                                                                      'create_patches_1[0][1]',
#                                                                      'create_patches_1[0][2]',
#                                                                      'create_patches_1[0][3]',
#                                                                      'create_patches_1[0][4]',
#                                                                      'create_patches_1[0][5]',
#                                                                      'create_patches_1[0][6]',
#                                                                      'create_patches_1[0][7]',
#                                                                      'create_patches_1[0][8]']
#
#  lambda_4 (Lambda)           (None, 64, 192, 1)           0         ['model_2[0][0]',
#                                                                      'model_2[1][0]',
#                                                                      'model_2[2][0]']
#
#  lambda_5 (Lambda)           (None, 64, 192, 1)           0         ['model_2[3][0]',
#                                                                      'model_2[4][0]',
#                                                                      'model_2[5][0]']
#
#  lambda_6 (Lambda)           (None, 64, 192, 1)           0         ['model_2[6][0]',
#                                                                      'model_2[7][0]',
#                                                                      'model_2[8][0]']
#
#  lambda_7 (Lambda)           (None, 192, 192, 1)          0         ['lambda_4[0][0]',
#                                                                      'lambda_5[0][0]',
#                                                                      'lambda_6[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 192, 192, 1)          2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 4546067 (17.34 MB)
# Trainable params: 4520243 (17.24 MB)
# Non-trainable params: 25824 (100.88 KB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_linknet_local.evaluate(test_gen_linknet_local, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 13:14:55.624556: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 28s 250ms/step - loss: 0.4732 - iou_score: 0.3744 - f1-score: 0.5404 - binary_accuracy: 0.8308
# [0.4731876254081726, 0.3743561804294586, 0.5404131412506104, 0.8307995796203613]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16
for image, label in test_gen_linknet_local:
    res = model_linknet_local.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 2023-12-08 13:15:22.588992: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 7s 7s/step

# %% [markdown]
# ## Model Linknet
# (https://github.com/subbareddy248/WSNET/blob/main/Code/Medical_CNN_Linknet.py)

# %%
from src.WSNET.Medical_CNN_Linknet import get_linknet_model
model_linknet, train_gen_linknet, val_gen_linknet, test_gen_linknet = get_linknet_model()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 9, 64, 64, 1), dtype=tf.float32, name=None), name='lambda_8/stack:0', description="created by layer 'lambda_8'")
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 192, 192, 3)]        0         []
#
#  create_patches_2 (CreatePa  [(None, 64, 64, 3),          0         ['input_5[0][0]']
#  tches)                       (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3)]
#
#  model_4 (Functional)        (None, 64, 64, 1)            4546065   ['create_patches_2[0][0]',
#                                                                      'create_patches_2[0][1]',
#                                                                      'create_patches_2[0][2]',
#                                                                      'create_patches_2[0][3]',
#                                                                      'create_patches_2[0][4]',
#                                                                      'create_patches_2[0][5]',
#                                                                      'create_patches_2[0][6]',
#                                                                      'create_patches_2[0][7]',
#                                                                      'create_patches_2[0][8]']
#
#  lambda_8 (Lambda)           (None, 9, 64, 64, 1)         0         ['model_4[0][0]',
#                                                                      'model_4[1][0]',
#                                                                      'model_4[2][0]',
#                                                                      'model_4[3][0]',
#                                                                      'model_4[4][0]',
#                                                                      'model_4[5][0]',
#                                                                      'model_4[6][0]',
#                                                                      'model_4[7][0]',
#                                                                      'model_4[8][0]']
#
#  input_6 (InputLayer)        [(None, 192, 192, 3)]        0         []
#
#  lambda_9 (Lambda)           (None, 192, 192, 1)          0         ['lambda_8[0][0]']
#
#  model_5 (Functional)        (None, 192, 192, 1)          4546065   ['input_6[0][0]']
#
#  concatenate (Concatenate)   (None, 192, 192, 2)          0         ['lambda_9[0][0]',
#                                                                      'model_5[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 192, 192, 1)          3         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 9092133 (34.68 MB)
# Trainable params: 9040485 (34.49 MB)
# Non-trainable params: 51648 (201.75 KB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_linknet.evaluate(test_gen_linknet, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 13:15:35.813468: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 49s 472ms/step - loss: 0.2643 - iou_score: 0.6058 - f1-score: 0.7521 - binary_accuracy: 0.8537
# [0.26434826850891113, 0.6057944893836975, 0.7520774602890015, 0.8537456393241882]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16

for image, label in test_gen_linknet:
    res = model_linknet.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[0][i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 2023-12-08 13:16:24.008392: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 10s 10s/step

# %% [markdown]
# ## Model PSPNET
# (https://github.com/subbareddy248/WSNET/blob/main/Code/Medical_CNN_PSPNET.py)

# %%
from src.WSNET.Medical_CNN_PSPNET import get_pspnet_model
model_pspnet, train_gen_pspnet, val_gen_pspnet, test_gen_pspnet = get_pspnet_model()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 192, 192, 3)]        0         []
#
#  create_patches_3 (CreatePa  [(None, 48, 48, 3),          0         ['input_9[0][0]']
#  tches)                       (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3)]
#
#  model_7 (Functional)        (None, 48, 48, 1)            1855937   ['create_patches_3[0][0]',
#                                                                      'create_patches_3[0][1]',
#                                                                      'create_patches_3[0][2]',
#                                                                      'create_patches_3[0][3]',
#                                                                      'create_patches_3[0][4]',
#                                                                      'create_patches_3[0][5]',
#                                                                      'create_patches_3[0][6]',
#                                                                      'create_patches_3[0][7]',
#                                                                      'create_patches_3[0][8]',
#                                                                      'create_patches_3[0][9]',
#                                                                      'create_patches_3[0][10]',
#                                                                      'create_patches_3[0][11]',
#                                                                      'create_patches_3[0][12]',
#                                                                      'create_patches_3[0][13]',
#                                                                      'create_patches_3[0][14]',
#                                                                      'create_patches_3[0][15]']
#
#  lambda_10 (Lambda)          (None, 16, 48, 48, 1)        0         ['model_7[0][0]',
#                                                                      'model_7[1][0]',
#                                                                      'model_7[2][0]',
#                                                                      'model_7[3][0]',
#                                                                      'model_7[4][0]',
#                                                                      'model_7[5][0]',
#                                                                      'model_7[6][0]',
#                                                                      'model_7[7][0]',
#                                                                      'model_7[8][0]',
#                                                                      'model_7[9][0]',
#                                                                      'model_7[10][0]',
#                                                                      'model_7[11][0]',
#                                                                      'model_7[12][0]',
#                                                                      'model_7[13][0]',
#                                                                      'model_7[14][0]',
#                                                                      'model_7[15][0]']
#
#  input_10 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  lambda_11 (Lambda)          (None, 192, 192, 1)          0         ['lambda_10[0][0]']
#
#  model_8 (Functional)        (None, 192, 192, 1)          1855937   ['input_10[0][0]']
#
#  concatenate_1 (Concatenate  (None, 192, 192, 2)          0         ['lambda_11[0][0]',
#  )                                                                   'model_8[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 192, 192, 1)          3         ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 3711877 (14.16 MB)
# Trainable params: 3695749 (14.10 MB)
# Non-trainable params: 16128 (63.00 KB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_pspnet.evaluate(test_gen_pspnet, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 13:16:37.933586: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 94s 1s/step - loss: 0.2849 - iou_score: 0.5766 - f1-score: 0.7290 - binary_accuracy: 0.8467
# [0.284943163394928, 0.5766072273254395, 0.7290488481521606, 0.8466705083847046]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16

for image, label in test_gen_pspnet:
    res = model_pspnet.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[0][i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# ## PSPNet local

# %%
from src.WSNET.Medical_CNN_PSPNET_local import get_pspnet_local_model
model_pspnet_local, train_gen_pspnet_local, val_gen_pspnet_local, test_gen_pspnet_local = get_pspnet_local_model()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_17 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  create_patches_6 (CreatePa  [(None, 48, 48, 3),          0         ['input_17[0][0]']
#  tches)                       (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3),
#                               (None, 48, 48, 3)]
#
#  model_14 (Functional)       (None, 48, 48, 1)            1855937   ['create_patches_6[0][0]',
#                                                                      'create_patches_6[0][1]',
#                                                                      'create_patches_6[0][2]',
#                                                                      'create_patches_6[0][3]',
#                                                                      'create_patches_6[0][4]',
#                                                                      'create_patches_6[0][5]',
#                                                                      'create_patches_6[0][6]',
#                                                                      'create_patches_6[0][7]',
#                                                                      'create_patches_6[0][8]',
#                                                                      'create_patches_6[0][9]',
#                                                                      'create_patches_6[0][10]',
#                                                                      'create_patches_6[0][11]',
#                                                                      'create_patches_6[0][12]',
#                                                                      'create_patches_6[0][13]',
#                                                                      'create_patches_6[0][14]',
#                                                                      'create_patches_6[0][15]']
#
#  lambda_22 (Lambda)          (None, 48, 192, 1)           0         ['model_14[0][0]',
#                                                                      'model_14[1][0]',
#                                                                      'model_14[2][0]',
#                                                                      'model_14[3][0]']
#
#  lambda_23 (Lambda)          (None, 48, 192, 1)           0         ['model_14[4][0]',
#                                                                      'model_14[5][0]',
#                                                                      'model_14[6][0]',
#                                                                      'model_14[7][0]']
#
#  lambda_24 (Lambda)          (None, 48, 192, 1)           0         ['model_14[8][0]',
#                                                                      'model_14[9][0]',
#                                                                      'model_14[10][0]',
#                                                                      'model_14[11][0]']
#
#  lambda_25 (Lambda)          (None, 48, 192, 1)           0         ['model_14[12][0]',
#                                                                      'model_14[13][0]',
#                                                                      'model_14[14][0]',
#                                                                      'model_14[15][0]']
#
#  lambda_26 (Lambda)          (None, 192, 192, 1)          0         ['lambda_22[0][0]',
#                                                                      'lambda_23[0][0]',
#                                                                      'lambda_24[0][0]',
#                                                                      'lambda_25[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 192, 192, 1)          2         ['lambda_26[0][0]']
#
# ==================================================================================================
# Total params: 1855939 (7.08 MB)
# Trainable params: 1847875 (7.05 MB)
# Non-trainable params: 8064 (31.50 KB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_pspnet_local.evaluate(test_gen_pspnet_local, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 13:41:34.049734: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 120s 1s/step - loss: 0.4875 - iou_score: 0.3699 - f1-score: 0.5363 - binary_accuracy: 0.8055
# [0.4875495433807373, 0.36992591619491577, 0.5362862348556519, 0.8054984211921692]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16

for image, label in test_gen_pspnet_local:
    res = model_pspnet_local.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 2023-12-08 13:43:32.768049: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x3477210d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 13s 13s/step

# %% [markdown]
# ## Unet local

# %%
from src.WSNET.Medical_CNN_Unet_Local import get_unet_local_model
model_unet_local, train_gen_unet_local, val_gen_unet_local, test_gen_unet_local = get_unet_local_model(False)
# Out:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_19 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  create_patches_7 (CreatePa  [(None, 64, 64, 3),          0         ['input_19[0][0]']
#  tches)                       (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3)]
#
#  model_16 (Functional)       (None, 64, 64, 1)            8336337   ['create_patches_7[0][0]',
#                                                                      'create_patches_7[0][1]',
#                                                                      'create_patches_7[0][2]',
#                                                                      'create_patches_7[0][3]',
#                                                                      'create_patches_7[0][4]',
#                                                                      'create_patches_7[0][5]',
#                                                                      'create_patches_7[0][6]',
#                                                                      'create_patches_7[0][7]',
#                                                                      'create_patches_7[0][8]']
#
#  lambda_27 (Lambda)          (None, 64, 192, 1)           0         ['model_16[0][0]',
#                                                                      'model_16[1][0]',
#                                                                      'model_16[2][0]']
#
#  lambda_28 (Lambda)          (None, 64, 192, 1)           0         ['model_16[3][0]',
#                                                                      'model_16[4][0]',
#                                                                      'model_16[5][0]']
#
#  lambda_29 (Lambda)          (None, 64, 192, 1)           0         ['model_16[6][0]',
#                                                                      'model_16[7][0]',
#                                                                      'model_16[8][0]']
#
#  lambda_30 (Lambda)          (None, 192, 192, 1)          0         ['lambda_27[0][0]',
#                                                                      'lambda_28[0][0]',
#                                                                      'lambda_29[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 192, 192, 1)          2         ['lambda_30[0][0]']
#
# ==================================================================================================
# Total params: 8336339 (31.80 MB)
# Trainable params: 5127379 (19.56 MB)
# Non-trainable params: 3208960 (12.24 MB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_unet_local.evaluate(test_gen_unet_local, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 13:43:53.402269: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 42s 373ms/step - loss: 0.4689 - iou_score: 0.3789 - f1-score: 0.5461 - binary_accuracy: 0.8305
# [0.4689478576183319, 0.3789178431034088, 0.5461074709892273, 0.8305185437202454]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16

for image, label in test_gen_unet_local:
    res = model_unet_local.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 2023-12-08 13:44:34.059333: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x296e28f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 9s 9s/step

# %% [markdown]
# ## Unet model

# %%
from src.WSNET.Medical_CNN_Unet import get_unet_model
model_unet, train_gen_unet, val_gen_unet, test_gen_unet = get_unet_model(False)
# Out:
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_21 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  create_patches_8 (CreatePa  [(None, 64, 64, 3),          0         ['input_21[0][0]']
#  tches)                       (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3)]
#
#  model_18 (Functional)       (None, 64, 64, 1)            8336337   ['create_patches_8[0][0]',
#                                                                      'create_patches_8[0][1]',
#                                                                      'create_patches_8[0][2]',
#                                                                      'create_patches_8[0][3]',
#                                                                      'create_patches_8[0][4]',
#                                                                      'create_patches_8[0][5]',
#                                                                      'create_patches_8[0][6]',
#                                                                      'create_patches_8[0][7]',
#                                                                      'create_patches_8[0][8]']
#
#  lambda_31 (Lambda)          (None, 9, 64, 64, 1)         0         ['model_18[0][0]',
#                                                                      'model_18[1][0]',
#                                                                      'model_18[2][0]',
#                                                                      'model_18[3][0]',
#                                                                      'model_18[4][0]',
#                                                                      'model_18[5][0]',
#                                                                      'model_18[6][0]',
#                                                                      'model_18[7][0]',
#                                                                      'model_18[8][0]']
#
#  input_22 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  lambda_32 (Lambda)          (None, 192, 192, 1)          0         ['lambda_31[0][0]']
#
#  model_19 (Functional)       (None, 192, 192, 1)          8336337   ['input_22[0][0]']
#
#  concatenate_2 (Concatenate  (None, 192, 192, 2)          0         ['lambda_32[0][0]',
#  )                                                                   'model_19[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 192, 192, 1)          3         ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 16672677 (63.60 MB)
# Trainable params: 16624933 (63.42 MB)
# Non-trainable params: 47744 (186.50 KB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_unet.evaluate(test_gen_unet, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 13:44:48.970435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 67s 646ms/step - loss: 0.2755 - iou_score: 0.5897 - f1-score: 0.7395 - binary_accuracy: 0.8564
# [0.27548736333847046, 0.589722216129303, 0.739486038684845, 0.8563769459724426]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16

for image, label in test_gen_unet:
    res = model_unet.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[0][i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 2023-12-08 13:46:13.180132: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 15s 15s/step

# %% [markdown]
# # FPN local

# %%
from src.WSNET.Medical_CNN_FPN_Local import get_fpn_local_model
model_fpn_local, train_gen_fpn_local, val_gen_fpn_local, test_gen_fpn_local = get_fpn_local_model(False)
# Out:
# Model: "model_22"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_25 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  create_patches_9 (CreatePa  [(None, 64, 64, 3),          0         ['input_25[0][0]']
#  tches)                       (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3)]
#
#  model_21 (Functional)       (None, 64, 64, 1)            6103105   ['create_patches_9[0][0]',
#                                                                      'create_patches_9[0][1]',
#                                                                      'create_patches_9[0][2]',
#                                                                      'create_patches_9[0][3]',
#                                                                      'create_patches_9[0][4]',
#                                                                      'create_patches_9[0][5]',
#                                                                      'create_patches_9[0][6]',
#                                                                      'create_patches_9[0][7]',
#                                                                      'create_patches_9[0][8]']
#
#  lambda_33 (Lambda)          (None, 64, 192, 1)           0         ['model_21[0][0]',
#                                                                      'model_21[1][0]',
#                                                                      'model_21[2][0]']
#
#  lambda_34 (Lambda)          (None, 64, 192, 1)           0         ['model_21[3][0]',
#                                                                      'model_21[4][0]',
#                                                                      'model_21[5][0]']
#
#  lambda_35 (Lambda)          (None, 64, 192, 1)           0         ['model_21[6][0]',
#                                                                      'model_21[7][0]',
#                                                                      'model_21[8][0]']
#
#  lambda_36 (Lambda)          (None, 192, 192, 1)          0         ['lambda_33[0][0]',
#                                                                      'lambda_34[0][0]',
#                                                                      'lambda_35[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 192, 192, 1)          2         ['lambda_36[0][0]']
#
# ==================================================================================================
# Total params: 6103107 (23.28 MB)
# Trainable params: 6078915 (23.19 MB)
# Non-trainable params: 24192 (94.50 KB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_fpn_local.evaluate(test_gen_fpn_local, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 17:38:49.865436: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 44s 398ms/step - loss: 0.4574 - iou_score: 0.3896 - f1-score: 0.5567 - binary_accuracy: 0.8168
# [0.45743265748023987, 0.3896227777004242, 0.5566738843917847, 0.8168339729309082]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16

for image, label in test_gen_fpn_local:
    res = model_fpn_local.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 2023-12-08 17:39:33.038534: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 10s 10s/step

# %% [markdown]
# # FPN Model

# %%
from src.WSNET.Medical_CNN_FPN import get_fpn_model
model_fpn, train_gen_fpn, val_gen_fpn, test_gen_fpn = get_fpn_model(False)
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_27 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  create_patches_10 (CreateP  [(None, 64, 64, 3),          0         ['input_27[0][0]']
#  atches)                      (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3),
#                               (None, 64, 64, 3)]
#
#  model_23 (Functional)       (None, 64, 64, 1)            6103105   ['create_patches_10[0][0]',
#                                                                      'create_patches_10[0][1]',
#                                                                      'create_patches_10[0][2]',
#                                                                      'create_patches_10[0][3]',
#                                                                      'create_patches_10[0][4]',
#                                                                      'create_patches_10[0][5]',
#                                                                      'create_patches_10[0][6]',
#                                                                      'create_patches_10[0][7]',
#                                                                      'create_patches_10[0][8]']
#
#  lambda_37 (Lambda)          (None, 9, 64, 64, 1)         0         ['model_23[0][0]',
#                                                                      'model_23[1][0]',
#                                                                      'model_23[2][0]',
#                                                                      'model_23[3][0]',
#                                                                      'model_23[4][0]',
#                                                                      'model_23[5][0]',
#                                                                      'model_23[6][0]',
#                                                                      'model_23[7][0]',
#                                                                      'model_23[8][0]']
#
#  input_28 (InputLayer)       [(None, 192, 192, 3)]        0         []
#
#  lambda_38 (Lambda)          (None, 192, 192, 1)          0         ['lambda_37[0][0]']
#
#  model_24 (Functional)       (None, 192, 192, 1)          6103105   ['input_28[0][0]']
#
#  concatenate_3 (Concatenate  (None, 192, 192, 2)          0         ['lambda_38[0][0]',
#  )                                                                   'model_24[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 192, 192, 1)          3         ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 12206213 (46.56 MB)
# Trainable params: 12157829 (46.38 MB)
# Non-trainable params: 48384 (189.00 KB)
# __________________________________________________________________________________________________
# 1880 1343 1343

# %%
import numpy as np
test_images_count = 1343
BATCH_SIZE = 16
results = model_fpn.evaluate(test_gen_fpn, steps=np.ceil(float(test_images_count) / float(BATCH_SIZE)))
print(results)
# Out:
# 2023-12-08 21:20:13.783221: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 64s 609ms/step - loss: 0.2542 - iou_score: 0.6167 - f1-score: 0.7609 - binary_accuracy: 0.8606
# [0.2542378306388855, 0.6166824698448181, 0.7609240412712097, 0.8605854511260986]

# %%
import matplotlib.pyplot as plt

BATCH_SIZE = 16

for image, label in test_gen_fpn:
    res = model_fpn.predict(image)
    plt.subplots(BATCH_SIZE, 3, figsize=(15,15))
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE,3,i*3 + 1)
        plt.imshow(image[0][i, :, :, :])
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 2)
        plt.imshow(res[i, :, : , :], cmap='gray')
        plt.axis('off')
        plt.subplot(BATCH_SIZE,3, i*3 + 3)
        plt.imshow(label[i, :, : , :], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    break
# Out:
# 2023-12-08 21:40:20.332811: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 12s 12s/step
